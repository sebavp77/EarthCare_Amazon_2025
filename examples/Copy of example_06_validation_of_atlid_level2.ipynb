# %% [markdown]
# # **Example 6** Validation of ATLID level 2 data
#
# This notebook shows how A-EBD profiles (backscatter, extinction, lidar ratio and depol. ratio) can be compared with ground-based data from `.nc`-files.

# %%
# !pip install earthcarekit
# Out:
# Collecting earthcarekit
#   Downloading earthcarekit-0.13.0-py3-none-any.whl.metadata (19 kB)
# Collecting numpy>=2.3.2 (from earthcarekit)
#   Downloading numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 3.1 MB/s eta 0:00:00
# Collecting pandas>=2.3.1 (from earthcarekit)
#   Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (91 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 91.2/91.2 kB 3.4 MB/s eta 0:00:00
# Requirement already satisfied: xarray>=2025.7.1 in /usr/local/lib/python3.12/dist-packages (from earthcarekit) (2025.12.0)
# Collecting matplotlib>=3.10.3 (from earthcarekit)
#   Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 4.5 MB/s eta 0:00:00
# Collecting plotly>=6.2.0 (from earthcarekit)
#   Downloading plotly-6.5.0-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: seaborn>=0.13.2 in /usr/local/lib/python3.12/dist-packages (from earthcarekit) (0.13.2)
# Collecting cartopy>=0.24.1 (from earthcarekit)
#   Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Collecting cmcrameri>=1.9 (from earthcarekit)
#   Downloading cmcrameri-1.9-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: scipy>=1.16.1 in /usr/local/lib/python3.12/dist-packages (from earthcarekit) (1.16.3)
# Collecting owslib>=0.34.1 (from earthcarekit)
#   Downloading owslib-0.35.0-py3-none-any.whl.metadata (6.8 kB)
# Collecting jupyterlab>=4.4.5 (from earthcarekit)
#   Downloading jupyterlab-4.5.1-py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: h5netcdf>=1.6.3 in /usr/local/lib/python3.12/dist-packages (from earthcarekit) (1.7.3)
# Collecting netcdf4>=1.7.2 (from earthcarekit)
#   Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.9 kB)
# Collecting tomli-w>=1.2.0 (from earthcarekit)
#   Downloading tomli_w-1.2.0-py3-none-any.whl.metadata (5.7 kB)
# Collecting mkdocstrings-python (from earthcarekit)
#   Downloading mkdocstrings_python-2.0.1-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: shapely>=2.0 in /usr/local/lib/python3.12/dist-packages (from cartopy>=0.24.1->earthcarekit) (2.1.2)
# Requirement already satisfied: packaging>=21 in /usr/local/lib/python3.12/dist-packages (from cartopy>=0.24.1->earthcarekit) (25.0)
# Requirement already satisfied: pyshp>=2.3 in /usr/local/lib/python3.12/dist-packages (from cartopy>=0.24.1->earthcarekit) (3.0.3)
# Requirement already satisfied: pyproj>=3.3.1 in /usr/local/lib/python3.12/dist-packages (from cartopy>=0.24.1->earthcarekit) (3.7.2)
# Requirement already satisfied: h5py in /usr/local/lib/python3.12/dist-packages (from h5netcdf>=1.6.3->earthcarekit) (3.15.1)
# Collecting async-lru>=1.0.0 (from jupyterlab>=4.4.5->earthcarekit)
#   Downloading async_lru-2.0.5-py3-none-any.whl.metadata (4.5 kB)
# Requirement already satisfied: httpx<1,>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (0.28.1)
# Requirement already satisfied: ipykernel!=6.30.0,>=6.5.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (6.17.1)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (3.1.6)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (5.9.1)
# Collecting jupyter-lsp>=2.0.0 (from jupyterlab>=4.4.5->earthcarekit)
#   Downloading jupyter_lsp-2.3.0-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (2.14.0)
# Collecting jupyterlab-server<3,>=2.28.0 (from jupyterlab>=4.4.5->earthcarekit)
#   Downloading jupyterlab_server-2.28.0-py3-none-any.whl.metadata (5.9 kB)
# Requirement already satisfied: notebook-shim>=0.2 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (75.2.0)
# Requirement already satisfied: tornado>=6.2.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (6.5.1)
# Requirement already satisfied: traitlets in /usr/local/lib/python3.12/dist-packages (from jupyterlab>=4.4.5->earthcarekit) (5.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.3->earthcarekit) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.3->earthcarekit) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.3->earthcarekit) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.3->earthcarekit) (1.4.9)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.3->earthcarekit) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.3->earthcarekit) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib>=3.10.3->earthcarekit) (2.9.0.post0)
# Collecting cftime (from netcdf4>=1.7.2->earthcarekit)
#   Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (8.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from netcdf4>=1.7.2->earthcarekit) (2025.11.12)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from owslib>=0.34.1->earthcarekit) (6.0.2)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.12/dist-packages (from owslib>=0.34.1->earthcarekit) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from owslib>=0.34.1->earthcarekit) (2.32.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.1->earthcarekit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=2.3.1->earthcarekit) (2025.2)
# Requirement already satisfied: narwhals>=1.15.1 in /usr/local/lib/python3.12/dist-packages (from plotly>=6.2.0->earthcarekit) (2.13.0)
# Collecting mkdocstrings>=0.30 (from mkdocstrings-python->earthcarekit)
#   Downloading mkdocstrings-1.0.0-py3-none-any.whl.metadata (16 kB)
# Collecting mkdocs-autorefs>=1.4 (from mkdocstrings-python->earthcarekit)
#   Downloading mkdocs_autorefs-1.4.3-py3-none-any.whl.metadata (13 kB)
# Collecting griffe>=1.13 (from mkdocstrings-python->earthcarekit)
#   Downloading griffe-1.15.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting colorama>=0.4 (from griffe>=1.13->mkdocstrings-python->earthcarekit)
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab>=4.4.5->earthcarekit) (4.12.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab>=4.4.5->earthcarekit) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.25.0->jupyterlab>=4.4.5->earthcarekit) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab>=4.4.5->earthcarekit) (0.16.0)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (7.34.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (7.4.9)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (0.2.1)
# Requirement already satisfied: nest-asyncio in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (1.6.0)
# Requirement already satisfied: psutil in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (5.9.5)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.12/dist-packages (from ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (26.2.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.0.3->jupyterlab>=4.4.5->earthcarekit) (3.0.3)
# Requirement already satisfied: argon2-cffi>=21.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.5.3)
# Requirement already satisfied: nbconvert>=6.4.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (7.16.6)
# Requirement already satisfied: nbformat>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.23.1)
# Requirement already satisfied: send2trash>=1.8.2 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.12/dist-packages (from jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.9.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.12/dist-packages (from jupyter-core->jupyterlab>=4.4.5->earthcarekit) (4.5.1)
# Requirement already satisfied: babel>=2.10 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.4.5->earthcarekit) (2.17.0)
# Collecting json5>=0.9.0 (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.4.5->earthcarekit)
#   Downloading json5-0.12.1-py3-none-any.whl.metadata (36 kB)
# Requirement already satisfied: jsonschema>=4.18.0 in /usr/local/lib/python3.12/dist-packages (from jupyterlab-server<3,>=2.28.0->jupyterlab>=4.4.5->earthcarekit) (4.25.1)
# Requirement already satisfied: Markdown>=3.3 in /usr/local/lib/python3.12/dist-packages (from mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit) (3.10)
# Collecting mkdocs>=1.1 (from mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit)
#   Downloading mkdocs-1.6.1-py3-none-any.whl.metadata (6.0 kB)
# Collecting pymdown-extensions>=6.3 (from mkdocstrings>=0.30->mkdocstrings-python->earthcarekit)
#   Downloading pymdown_extensions-10.19.1-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib>=3.10.3->earthcarekit) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->owslib>=0.34.1->earthcarekit) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->owslib>=0.34.1->earthcarekit) (2.5.0)
# Requirement already satisfied: typing_extensions>=4.5 in /usr/local/lib/python3.12/dist-packages (from anyio->httpx<1,>=0.25.0->jupyterlab>=4.4.5->earthcarekit) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.12/dist-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (25.1.0)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (2.19.2)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (4.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.4.5->earthcarekit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.4.5->earthcarekit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.4.5->earthcarekit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.28.0->jupyterlab>=4.4.5->earthcarekit) (0.30.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.12/dist-packages (from jupyter-client>=6.1.12->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (0.4)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (4.0.0)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.12/dist-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.1.1)
# Requirement already satisfied: click>=7.0 in /usr/local/lib/python3.12/dist-packages (from mkdocs>=1.1->mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit) (8.3.1)
# Collecting ghp-import>=1.0 (from mkdocs>=1.1->mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit)
#   Downloading ghp_import-2.1.0-py3-none-any.whl.metadata (7.2 kB)
# Collecting mergedeep>=1.3.4 (from mkdocs>=1.1->mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit)
#   Downloading mergedeep-1.3.4-py3-none-any.whl.metadata (4.3 kB)
# Collecting mkdocs-get-deps>=0.2.0 (from mkdocs>=1.1->mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit)
#   Downloading mkdocs_get_deps-0.2.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting pathspec>=0.11.1 (from mkdocs>=1.1->mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Collecting pyyaml-env-tag>=0.1 (from mkdocs>=1.1->mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit)
#   Downloading pyyaml_env_tag-1.1-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: watchdog>=2.0 in /usr/local/lib/python3.12/dist-packages (from mkdocs>=1.1->mkdocs-autorefs>=1.4->mkdocstrings-python->earthcarekit) (6.0.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (6.3.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.12/dist-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.12/dist-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (2.21.2)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.12/dist-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.7.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.12/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from bleach[css]!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.4.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (0.8.5)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (25.10.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel!=6.30.0,>=6.5.0->jupyterlab>=4.4.5->earthcarekit) (0.2.14)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (2.0.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (2.8)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (2.23)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.12/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.12/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->jupyterlab>=4.4.5->earthcarekit) (1.4.0)
# Downloading earthcarekit-0.13.0-py3-none-any.whl (347 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 347.4/347.4 kB 13.5 MB/s eta 0:00:00
# Downloading cartopy-0.25.0-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 107.5 MB/s eta 0:00:00
# Downloading cmcrameri-1.9-py3-none-any.whl (277 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 277.4/277.4 kB 24.2 MB/s eta 0:00:00
# Downloading jupyterlab-4.5.1-py3-none-any.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 124.5 MB/s eta 0:00:00
# Downloading matplotlib-3.10.8-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.7/8.7 MB 132.9 MB/s eta 0:00:00
# Downloading netcdf4-1.7.3-cp311-abi3-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (9.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 98.2 MB/s eta 0:00:00
# Downloading numpy-2.3.5-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 112.4 MB/s eta 0:00:00
# Downloading owslib-0.35.0-py3-none-any.whl (240 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 240.5/240.5 kB 22.2 MB/s eta 0:00:00
# Downloading pandas-2.3.3-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (12.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 123.6 MB/s eta 0:00:00
# Downloading plotly-6.5.0-py3-none-any.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 127.7 MB/s eta 0:00:00
# Downloading tomli_w-1.2.0-py3-none-any.whl (6.7 kB)
# Downloading mkdocstrings_python-2.0.1-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 11.2 MB/s eta 0:00:00
# Downloading async_lru-2.0.5-py3-none-any.whl (6.1 kB)
# Downloading griffe-1.15.0-py3-none-any.whl (150 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.7/150.7 kB 16.2 MB/s eta 0:00:00
# Downloading jupyter_lsp-2.3.0-py3-none-any.whl (76 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.7/76.7 kB 7.0 MB/s eta 0:00:00
# Downloading jupyterlab_server-2.28.0-py3-none-any.whl (59 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.8/59.8 kB 5.6 MB/s eta 0:00:00
# Downloading mkdocs_autorefs-1.4.3-py3-none-any.whl (25 kB)
# Downloading mkdocstrings-1.0.0-py3-none-any.whl (35 kB)
# Downloading cftime-1.6.5-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 80.6 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading json5-0.12.1-py3-none-any.whl (36 kB)
# Downloading mkdocs-1.6.1-py3-none-any.whl (3.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.9/3.9 MB 73.3 MB/s eta 0:00:00
# Downloading pymdown_extensions-10.19.1-py3-none-any.whl (266 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 266.7/266.7 kB 20.7 MB/s eta 0:00:00
# Downloading ghp_import-2.1.0-py3-none-any.whl (11 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 62.1 MB/s eta 0:00:00
# Downloading mergedeep-1.3.4-py3-none-any.whl (6.4 kB)
# Downloading mkdocs_get_deps-0.2.0-py3-none-any.whl (9.5 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading pyyaml_env_tag-1.1-py3-none-any.whl (4.7 kB)
# Installing collected packages: tomli-w, pyyaml-env-tag, pymdown-extensions, plotly, pathspec, numpy, mergedeep, json5, jedi, colorama, async-lru, pandas, owslib, mkdocs-get-deps, griffe, ghp-import, cftime, netcdf4, mkdocs, matplotlib, mkdocs-autorefs, cmcrameri, cartopy, mkdocstrings, mkdocstrings-python, jupyterlab-server, jupyter-lsp, jupyterlab, earthcarekit
#   Attempting uninstall: plotly
#     Found existing installation: plotly 5.24.1
#     Uninstalling plotly-5.24.1:
#       Successfully uninstalled plotly-5.24.1
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.2.2
#     Uninstalling pandas-2.2.2:
#       Successfully uninstalled pandas-2.2.2
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.0
#     Uninstalling matplotlib-3.10.0:
#       Successfully uninstalled matplotlib-3.10.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.3.3 which is incompatible.
# tensorflow 2.19.0 requires numpy<2.2.0,>=1.26.0, but you have numpy 2.3.5 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 2.3.5 which is incompatible.
# numba 0.60.0 requires numpy<2.1,>=1.22, but you have numpy 2.3.5 which is incompatible.
# Successfully installed async-lru-2.0.5 cartopy-0.25.0 cftime-1.6.5 cmcrameri-1.9 colorama-0.4.6 earthcarekit-0.13.0 ghp-import-2.1.0 griffe-1.15.0 jedi-0.19.2 json5-0.12.1 jupyter-lsp-2.3.0 jupyterlab-4.5.1 jupyterlab-server-2.28.0 matplotlib-3.10.8 mergedeep-1.3.4 mkdocs-1.6.1 mkdocs-autorefs-1.4.3 mkdocs-get-deps-0.2.0 mkdocstrings-1.0.0 mkdocstrings-python-2.0.1 netcdf4-1.7.3 numpy-2.3.5 owslib-0.35.0 pandas-2.3.3 pathspec-0.12.1 plotly-6.5.0 pymdown-extensions-10.19.1 pyyaml-env-tag-1.1 tomli-w-1.2.0

# %%
import earthcarekit as eck

# %% [markdown]
# ## Requirements
#
# For this example you need a A-EBD file from an overpass and the matching ground data (e.g., PollyNET `.nc`-file).
#
# Paste both file paths into the cell below:

# %%
fp_aebd = r"./ECA_EXBA_ATL_EBD_2A_20240902T210023Z_20250721T110708Z_01508B.h5"
fp_ground = r"./2024_09_02_Mon_TJK_00_00_01_2000_2130_profiles.nc"

# Also specify the ground site by either setting its name (string) or creating a custom GroundSite object:
site = "dushanbe"
radius_km = 100.0

# %% [markdown]
# ## **6.1** Open and view datasets

# %%
print("Open the A-EBD dataset:")
with eck.read_product(fp_aebd) as ds_aebd:
    display(ds_aebd)

print("Open the ground-based dataset:")
with eck.read_nc(fp_ground) as ds_ground:
    display(ds_ground)

# %%
import logging
with eck.read_product(fp_aebd) as ds_aebd:
    print("Create a quicklook of the overpass from the A-EBD file:")
    print("Note: When plotting profiles from A-PRO products, the `ecquicklook` function will automatically plot only the closest profile within the set radius.")
    ql = eck.ecquicklook(
        ds=ds_aebd,
        site=site,
        radius_km=radius_km,
        resolution="low",  # Change the A-EBD resolution as needed
        height_range=(0, 12e3),  # Change the plotting height as needed
        selection_max_time_margin="00:01:00",  # Crop the plot to show only 1 Minute around the overpass start and end times
        logger=logging.getLogger(),  # Optional: Shows plotting progress
        show_steps=True,
        mode="exact",
    )
    print("Save the quicklook:")
    eck.save_plot(ql.fig, filepath="./01508B_20250902_aebd_quicklook.png")

# %% [markdown]
# ## **6.2** Create backscatter, extinction, lidar ratio and depol. ratio profile plots and comparison statistics

# %%
# Note: Ensure that all your input bsc. and ext. data are given as [m-1sr-1]/[m-1] instead of [Mm-1sr-1]/[Mm-1].
#       You can convert your results (plot and stats) to mega by setting the argument to_mega=True.
with (
    eck.read_product(fp_aebd) as ds_aebd,  # Here you could read other or additional EarthCARE files like A-AER
    eck.read_any(fp_ground) as ds_ground,
):
    results = eck.compare_bsc_ext_lr_depol(
        input_ec=ds_aebd,
        resolution="low",  # Change the A-EBD resolution as needed

        input_ec2=ds_aebd,  # Here from the same A-EBD dataset ...
        resolution2="medium",  # ... the high resolution is taken

        input_ground=ds_ground,
        site=site,
        time_var_ground="start_time",  # Set to the time variable name in the ground-based dataset
        height_var_ground="height",  # Set to the height variable name in the ground-based dataset
        bsc_var_ground=["aerBsc_klett_355", "aerBsc_raman_355"],  # Provide list of variables name from the ground-based dataset
        ext_var_ground=["aerExt_klett_355", "aerExt_raman_355"],
        lr_var_ground=["aerLR_klett_355", "aerLR_raman_355"],
        depol_var_ground=["parDepol_klett_355", "parDepol_raman_355"],
        height_range=(0, 12e3),  # Change the plotting height as needed
        selection_height_range=(2e3, 4e3),  # Change the selected height range to get statistics from as needed or set to None
        value_range_bsc=(0, 8e-6),  # Must be given as [m-1sr-1] and will be auto. converted to [Mm-1sr-1] if to_mega=True
        value_range_ext=(0, 3e-4),  # Must be given as [m-1] and will be auto. converted to [Mm-1] if to_mega=True
        value_range_lr=(0, 100),
        value_range_depol=(0, 0.6),
        to_mega=True,  # e.g., plots [m-1sr-1] as [Mm-1sr-1]
    )
    display(results.stats)

# %%
print("Save the plot:")
eck.save_plot(results.fig, filepath="./01508B_20250902_aebd_vs_polly_profiles.png")

print("Save the stat. results:")
results.stats.to_csv("./01508B_20250902_aebd_vs_polly_profiles.csv", index=False)

# %% [markdown]
# ## **6.3** Edit ground-based profiles, add errors and other plotting customizations

# %%
import numpy as np
with (
    eck.read_product(fp_aebd) as ds_aebd,
    eck.read_any(fp_ground) as ds_ground,
):
    # Add a new variable to the ground-based dataset and edit it.
    # Here data outside a certain height range is set no NaN:
    h = ds_ground["height"].values
    mask = np.logical_not(
        np.logical_and(
            h >= 1.8e3,
            h <= 4.3e3,
        )
    )
    ds_ground["NEW_aerLR_raman_355"] = ds_ground["aerLR_raman_355"].copy()  # Ensure you copy the variable with `.copy()` otherwise the original will also be overwritten
    ds_ground["NEW_aerLR_raman_355"].values[mask] = np.nan

    results = eck.compare_bsc_ext_lr_depol(
        input_ec=ds_aebd,
        input_ground=ds_ground,
        site=site,
        time_var_ground="start_time",  # Set to the time variable name in the ground-based dataset
        height_var_ground="height",  # Set to the height variable name in the ground-based dataset
        resolution="low",  # Change the A-EBD resolution as needed
        # Instead of giving a single variable name you can give a tuple of 2 variable names, where the first corresponds to the signal and the second to its related error variable name
        bsc_var_ground=[
            ("aerBsc_klett_355", "uncertainty_aerBsc_klett_355"),
            ("aerBsc_raman_355", "uncertainty_aerBsc_raman_355"),
        ],
        ext_var_ground=[("aerExt_klett_355", "uncertainty_aerExt_klett_355"), ("aerExt_raman_355", "uncertainty_aerExt_raman_355")],
        lr_var_ground=[("aerLR_klett_355", "uncertainty_aerLR_klett_355"), "NEW_aerLR_raman_355"],  # Here the new variable is used
        depol_var_ground=[("parDepol_klett_355", "uncertainty_parDepol_klett_355"), ("parDepol_raman_355", "uncertainty_parDepol_raman_355")],
        height_range=(0, 12e3),  # Change the plotting height as needed
        selection_height_range=(2e3, 4e3),  # Change the selected height range to get statistics from as needed or set to None
        show_error_ec=True,  # Plots errors as ribbons for the EarthCARE profiles
        to_mega=True,
        # colors_ec=["ec:earthcare", "ec:purple", "black"],  # Edit colors of EarthCARE profiles
        # colors_ground=["tab:blue", "green", "#ff0000"],  # Edit colors of ground-based profiles
        # show_steps=False,  # Plot height bin centers instead of step function
        # single_figsize=(2, 4),  # You may edit the sub figure sizes
    )
    display(results.stats)
